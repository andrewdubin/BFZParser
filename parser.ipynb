# %%
import pandas as pd
import numpy as np
from values import dismissal

# %%
#Step 1: Import document, Change Program Start Date to Date of Identification
df = pd.read_csv("BFZ_Aggregator_Report.csv")
df = df.rename(columns={"Program Start Date":"Date of Identification"})
df = df.drop(["Relationship","Family Name",'Name'],axis=1)
df
# Out:
#      Case Number                             Program Name  \
# 0          48450  Arlington Zero: Chronic - Veterans Only
# 1           7649  Arlington Zero: Chronic - Veterans Only
# 2           8039  Arlington Zero: Chronic - Veterans Only
# 3          48894            Arlington Zero: Single Adults
# 4          52633                 Arlington Zero: Families
# ..           ...                                      ...
# 442        43654  Arlington Zero: Chronic - Veterans Only
# 443        50467            Arlington Zero: Single Adults
# 444        51829  Arlington Zero: Chronic - Veterans Only
# 445        10194  Arlington Zero: Chronic - Veterans Only
# 446        48574  Arlington Zero: Chronic - Veterans Only
#
#     Veteran Status (HUD) Date of Identification Program End Date  \
# 0                     No         1/31/2019 0:00   6/19/2019 0:00
# 1                     No         8/27/2015 0:00  10/30/2015 0:00
# 2                     No         1/20/2015 0:00   1/22/2015 0:00
# 3                     No          7/1/2019 0:00   7/24/2020 0:00
# 4                     No         6/23/2021 0:00              NaN
# ..                   ...                    ...              ...
# 442                   No         3/28/2017 0:00   6/12/2017 0:00
# 443                   No          7/1/2019 0:00   2/26/2020 0:00
# 444                  Yes         3/17/2020 0:00  11/19/2020 0:00
# 445                   No         11/2/2015 0:00    8/8/2016 0:00
# 446                   No         9/20/2018 0:00   5/29/2019 0:00
#
#                    Dismissal Reason
# 0         Exit to Permanent Housing
# 1         Exit to Permanent Housing
# 2    Service Completed Successfully
# 3         Exit to Permanent Housing
# 4                               NaN
# ..                              ...
# 442       Exit to Permanent Housing
# 443       Exit to Permanent Housing
# 444       Exit to Permanent Housing
# 445       Exit to Permanent Housing
# 446               Left Jurisdiction
#
# [447 rows x 6 columns]

# %%
#Step 2: Adding Household Type Column
household_type = {"Arlington Zero: Chronic - Veterans Only":"Single Adults",
"Arlington Zero: Single Adults":"Single Adults",
"Arlington Zero: Families":"Families",
"Arlington Zero: TAY":"Youth"}
df['Household Type'] = df['Program Name'].map(household_type)
df
# Out:
#      Case Number                             Program Name  \
# 0          48450  Arlington Zero: Chronic - Veterans Only
# 1           7649  Arlington Zero: Chronic - Veterans Only
# 2           8039  Arlington Zero: Chronic - Veterans Only
# 3          48894            Arlington Zero: Single Adults
# 4          52633                 Arlington Zero: Families
# ..           ...                                      ...
# 442        43654  Arlington Zero: Chronic - Veterans Only
# 443        50467            Arlington Zero: Single Adults
# 444        51829  Arlington Zero: Chronic - Veterans Only
# 445        10194  Arlington Zero: Chronic - Veterans Only
# 446        48574  Arlington Zero: Chronic - Veterans Only
#
#     Veteran Status (HUD) Date of Identification Program End Date  \
# 0                     No         1/31/2019 0:00   6/19/2019 0:00
# 1                     No         8/27/2015 0:00  10/30/2015 0:00
# 2                     No         1/20/2015 0:00   1/22/2015 0:00
# 3                     No          7/1/2019 0:00   7/24/2020 0:00
# 4                     No         6/23/2021 0:00              NaN
# ..                   ...                    ...              ...
# 442                   No         3/28/2017 0:00   6/12/2017 0:00
# 443                   No          7/1/2019 0:00   2/26/2020 0:00
# 444                  Yes         3/17/2020 0:00  11/19/2020 0:00
# 445                   No         11/2/2015 0:00    8/8/2016 0:00
# 446                   No         9/20/2018 0:00   5/29/2019 0:00
#
#                    Dismissal Reason Household Type
# 0         Exit to Permanent Housing  Single Adults
# 1         Exit to Permanent Housing  Single Adults
# 2    Service Completed Successfully  Single Adults
# 3         Exit to Permanent Housing  Single Adults
# 4                               NaN       Families
# ..                              ...            ...
# 442       Exit to Permanent Housing  Single Adults
# 443       Exit to Permanent Housing  Single Adults
# 444       Exit to Permanent Housing  Single Adults
# 445       Exit to Permanent Housing  Single Adults
# 446               Left Jurisdiction  Single Adults
#
# [447 rows x 7 columns]

# %%
#Step 3: Adding Case Number Counter
# case_counter = df.groupby('Case Number').count()['Program Name']
df['Case Number Counter'] = df['Case Number'].map(df.groupby('Case Number').count()['Program Name'])
df[df['Case Number Counter'] > 1]
# Out:
#      Case Number                             Program Name  \
# 36         44078  Arlington Zero: Chronic - Veterans Only
# 37         44078  Arlington Zero: Chronic - Veterans Only
# 49         10489  Arlington Zero: Chronic - Veterans Only
# 50         10489            Arlington Zero: Single Adults
# 51         10489  Arlington Zero: Chronic - Veterans Only
# ..           ...                                      ...
# 433         8563  Arlington Zero: Chronic - Veterans Only
# 434         8563  Arlington Zero: Chronic - Veterans Only
# 435         8563  Arlington Zero: Chronic - Veterans Only
# 439        40681                 Arlington Zero: Families
# 440        40681                      Arlington Zero: TAY
#
#     Veteran Status (HUD) Date of Identification Program End Date  \
# 36                    No         8/17/2016 0:00   8/17/2016 0:00
# 37                    No         3/22/2016 0:00   5/12/2017 0:00
# 49                    No         7/10/2020 0:00              NaN
# 50                    No          7/1/2019 0:00   6/22/2021 0:00
# 51                    No         7/10/2020 0:00              NaN
# ..                   ...                    ...              ...
# 433                   No        11/30/2016 0:00   2/27/2017 0:00
# 434                   No        10/15/2015 0:00   3/29/2016 0:00
# 435                   No         9/19/2017 0:00   6/30/2018 0:00
# 439   Data Not Collected          9/4/2021 0:00              NaN
# 440   Data Not Collected          5/7/2021 0:00              NaN
#
#                   Dismissal Reason Household Type  Case Number Counter
# 36               Removed from Pool  Single Adults                    2
# 37       Exit to Permanent Housing  Single Adults                    2
# 49                             NaN  Single Adults                    4
# 50               Removed from Pool  Single Adults                    4
# 51                             NaN  Single Adults                    4
# ..                             ...            ...                  ...
# 433  Discharged for Non-Compliance  Single Adults                    3
# 434              Removed from Pool  Single Adults                    3
# 435                            NaN  Single Adults                    3
# 439                            NaN       Families                    2
# 440                            NaN          Youth                    2
#
# [100 rows x 8 columns]

# %%
#Step 4: Adding Chronic Column
#If client is in Chronic & Vet and 'No' to Veteran Status, then they are chronic
df['Chronic'] = np.nan
df.loc[(df['Program Name']=="Arlington Zero: Chronic - Veterans Only") & (df['Veteran Status (HUD)']=="No")
,"Chronic"] = "Yes"
df['Chronic'].value_counts()
# Out:
# Yes    233
# Name: Chronic, dtype: int64

# %%
#Step 5, remap all dismissal reasons
df['Dismissal Reason'] = df['Dismissal Reason'].map(dismissal)
df.head()
# Out:
#    Case Number                             Program Name Veteran Status (HUD)  \
# 0        48450  Arlington Zero: Chronic - Veterans Only                   No
# 1         7649  Arlington Zero: Chronic - Veterans Only                   No
# 2         8039  Arlington Zero: Chronic - Veterans Only                   No
# 3        48894            Arlington Zero: Single Adults                   No
# 4        52633                 Arlington Zero: Families                   No
#
#   Date of Identification Program End Date Dismissal Reason Household Type  \
# 0         1/31/2019 0:00   6/19/2019 0:00           Housed  Single Adults
# 1         8/27/2015 0:00  10/30/2015 0:00           Housed  Single Adults
# 2         1/20/2015 0:00   1/22/2015 0:00           Housed  Single Adults
# 3          7/1/2019 0:00   7/24/2020 0:00           Housed  Single Adults
# 4         6/23/2021 0:00              NaN              NaN       Families
#
#    Case Number Counter Chronic
# 0                    1     Yes
# 1                    1     Yes
# 2                    1     Yes
# 3                    1     NaN
# 4                    1     NaN

# %%
#Step 6, Populate Housing Move-In Date
df['Housing Move-In Date'] = df["Program End Date"][df["Dismissal Reason"]=="Housed"]
df['Housing Move-In Date']
# Out:
#     Housing Move-In Date Program End Date
# 0         6/19/2019 0:00   6/19/2019 0:00
# 1        10/30/2015 0:00  10/30/2015 0:00
# 2         1/22/2015 0:00   1/22/2015 0:00
# 3         7/24/2020 0:00   7/24/2020 0:00
# 4                    NaN              NaN
# ..                   ...              ...
# 442       6/12/2017 0:00   6/12/2017 0:00
# 443       2/26/2020 0:00   2/26/2020 0:00
# 444      11/19/2020 0:00  11/19/2020 0:00
# 445        8/8/2016 0:00    8/8/2016 0:00
# 446                  NaN   5/29/2019 0:00
#
# [447 rows x 2 columns]

# %%
#Step 7, Populate Inactive Date
#Do we consider those with program end date and null dismissal reasons as inactive?
df['Inactive Date'] = df['Program End Date'][df["Dismissal Reason"]!="Housed"]
df['Inactive Date']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 442               NaN
# 443               NaN
# 444               NaN
# 445               NaN
# 446    5/29/2019 0:00
# Name: Inactive Date, Length: 447, dtype: object

# %%
#Step 8, Calculate Returned to Active Date (Date of Idenfication on second record)
