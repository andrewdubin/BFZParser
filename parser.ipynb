# %%
import pandas as pd
import numpy as np
from values import dismissal

# %%
#Step 1: Import document, Change Program Start Date to Date of Identification
df = pd.read_csv("BFZ_Aggregator_Report.csv")
df = df.rename(columns={"Program Start Date":"Date of Identification",'Case Number':'Client ID','Veteran Status (HUD)':'Veteran Status'})
df = df.drop(["Relationship","Family Name",'Name'],axis=1)
df = df.drop_duplicates()
df = df.reset_index()
df = df.drop(['index'],axis=1)
df
# Out:
#      Client ID                             Program Name Veteran Status  \
# 0        48450  Arlington Zero: Chronic - Veterans Only             No
# 1         7649  Arlington Zero: Chronic - Veterans Only             No
# 2         8039  Arlington Zero: Chronic - Veterans Only             No
# 3        48894            Arlington Zero: Single Adults             No
# 4        52633                 Arlington Zero: Families             No
# ..         ...                                      ...            ...
# 431      43654  Arlington Zero: Chronic - Veterans Only             No
# 432      50467            Arlington Zero: Single Adults             No
# 433      51829  Arlington Zero: Chronic - Veterans Only            Yes
# 434      10194  Arlington Zero: Chronic - Veterans Only             No
# 435      48574  Arlington Zero: Chronic - Veterans Only             No
#
#     Date of Identification Program End Date                Dismissal Reason
# 0           1/31/2019 0:00   6/19/2019 0:00       Exit to Permanent Housing
# 1           8/27/2015 0:00  10/30/2015 0:00       Exit to Permanent Housing
# 2           1/20/2015 0:00   1/22/2015 0:00  Service Completed Successfully
# 3            7/1/2019 0:00   7/24/2020 0:00       Exit to Permanent Housing
# 4           6/23/2021 0:00              NaN                             NaN
# ..                     ...              ...                             ...
# 431         3/28/2017 0:00   6/12/2017 0:00       Exit to Permanent Housing
# 432          7/1/2019 0:00   2/26/2020 0:00       Exit to Permanent Housing
# 433         3/17/2020 0:00  11/19/2020 0:00       Exit to Permanent Housing
# 434         11/2/2015 0:00    8/8/2016 0:00       Exit to Permanent Housing
# 435         9/20/2018 0:00   5/29/2019 0:00               Left Jurisdiction
#
# [436 rows x 6 columns]

# %%
#Step 2: Adding Household Type Column
household_type = {"Arlington Zero: Chronic - Veterans Only":"Single Adults",
"Arlington Zero: Single Adults":"Single Adults",
"Arlington Zero: Families":"Families",
"Arlington Zero: TAY":"Youth"}
df['Household Type'] = df['Program Name'].map(household_type)
df
# Out:
#      Client ID                             Program Name Veteran Status  \
# 0        48450  Arlington Zero: Chronic - Veterans Only             No
# 1         7649  Arlington Zero: Chronic - Veterans Only             No
# 2         8039  Arlington Zero: Chronic - Veterans Only             No
# 3        48894            Arlington Zero: Single Adults             No
# 4        52633                 Arlington Zero: Families             No
# ..         ...                                      ...            ...
# 431      43654  Arlington Zero: Chronic - Veterans Only             No
# 432      50467            Arlington Zero: Single Adults             No
# 433      51829  Arlington Zero: Chronic - Veterans Only            Yes
# 434      10194  Arlington Zero: Chronic - Veterans Only             No
# 435      48574  Arlington Zero: Chronic - Veterans Only             No
#
#     Date of Identification Program End Date                Dismissal Reason  \
# 0           1/31/2019 0:00   6/19/2019 0:00       Exit to Permanent Housing
# 1           8/27/2015 0:00  10/30/2015 0:00       Exit to Permanent Housing
# 2           1/20/2015 0:00   1/22/2015 0:00  Service Completed Successfully
# 3            7/1/2019 0:00   7/24/2020 0:00       Exit to Permanent Housing
# 4           6/23/2021 0:00              NaN                             NaN
# ..                     ...              ...                             ...
# 431         3/28/2017 0:00   6/12/2017 0:00       Exit to Permanent Housing
# 432          7/1/2019 0:00   2/26/2020 0:00       Exit to Permanent Housing
# 433         3/17/2020 0:00  11/19/2020 0:00       Exit to Permanent Housing
# 434         11/2/2015 0:00    8/8/2016 0:00       Exit to Permanent Housing
# 435         9/20/2018 0:00   5/29/2019 0:00               Left Jurisdiction
#
#     Household Type
# 0    Single Adults
# 1    Single Adults
# 2    Single Adults
# 3    Single Adults
# 4         Families
# ..             ...
# 431  Single Adults
# 432  Single Adults
# 433  Single Adults
# 434  Single Adults
# 435  Single Adults
#
# [436 rows x 7 columns]

# %%
#Step 3: Adding Case Number Counter
# df['Case Number Counter'] = df['Case Number'].map(df.groupby('Case Number').count()['Program Name'])
df['Client ID Counter'] = df['Client ID'].map(df.groupby('Client ID').agg({'Client ID':'count'})['Client ID'])
df[df['Client ID Counter'] > 1]
# household_counter = df.groupby(['Client ID','Household Type']).count()
# case_counter = df.groupby('Client ID').count()
# Out:
#      Client ID                             Program Name      Veteran Status  \
# 36       44078  Arlington Zero: Chronic - Veterans Only                  No
# 37       44078  Arlington Zero: Chronic - Veterans Only                  No
# 49       10489  Arlington Zero: Chronic - Veterans Only                  No
# 50       10489            Arlington Zero: Single Adults                  No
# 57       42657  Arlington Zero: Chronic - Veterans Only                  No
# ..         ...                                      ...                 ...
# 422       8563  Arlington Zero: Chronic - Veterans Only                  No
# 423       8563  Arlington Zero: Chronic - Veterans Only                  No
# 424       8563  Arlington Zero: Chronic - Veterans Only                  No
# 428      40681                 Arlington Zero: Families  Data Not Collected
# 429      40681                      Arlington Zero: TAY  Data Not Collected
#
#     Date of Identification Program End Date               Dismissal Reason  \
# 36          8/17/2016 0:00   8/17/2016 0:00              Removed from Pool
# 37          3/22/2016 0:00   5/12/2017 0:00      Exit to Permanent Housing
# 49          7/10/2020 0:00              NaN                            NaN
# 50           7/1/2019 0:00   6/22/2021 0:00              Removed from Pool
# 57           7/1/2018 0:00   10/8/2021 0:00      Exit to Permanent Housing
# ..                     ...              ...                            ...
# 422        11/30/2016 0:00   2/27/2017 0:00  Discharged for Non-Compliance
# 423        10/15/2015 0:00   3/29/2016 0:00              Removed from Pool
# 424         9/19/2017 0:00   6/30/2018 0:00                            NaN
# 428          9/4/2021 0:00              NaN                            NaN
# 429          5/7/2021 0:00              NaN                            NaN
#
#     Household Type  Client ID Counter
# 36   Single Adults                  2
# 37   Single Adults                  2
# 49   Single Adults                  2
# 50   Single Adults                  2
# 57   Single Adults                  2
# ..             ...                ...
# 422  Single Adults                  3
# 423  Single Adults                  3
# 424  Single Adults                  3
# 428       Families                  2
# 429          Youth                  2
#
# [80 rows x 8 columns]

# %%
#Step 4: Adding Chronic Column
#If client is in Chronic & Vet and 'No' to Veteran Status, then they are chronic
df['Chronic Status'] = np.nan
df.loc[(df['Program Name']=="Arlington Zero: Chronic - Veterans Only") & (df['Veteran Status']=="No")
,"Chronic Status"] = "Yes"
df['Chronic Status'].value_counts()
# Out:
# Yes    225
# Name: Chronic Status, dtype: int64

# %%
#Step 5, remap all dismissal reasons
df['Dismissal Reason'] = df['Dismissal Reason'].map(dismissal)

# %%
#Step 6, Populate Housing Move-In Date
df['Housing Move-In Date'] = df["Program End Date"][df["Dismissal Reason"]=="Housed"]
df['Housing Move-In Date']
# Out:
# 0       6/19/2019 0:00
# 1      10/30/2015 0:00
# 2       1/22/2015 0:00
# 3       7/24/2020 0:00
# 4                  NaN
#             ...
# 431     6/12/2017 0:00
# 432     2/26/2020 0:00
# 433    11/19/2020 0:00
# 434      8/8/2016 0:00
# 435                NaN
# Name: Housing Move-In Date, Length: 436, dtype: object

# %%
#Step 7, Populate Inactive Date
#Do we consider those with program end date and null dismissal reasons as inactive?
df['Inactive Date'] = df['Program End Date'][df["Dismissal Reason"]!="Housed"]
df['Inactive Date']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 431               NaN
# 432               NaN
# 433               NaN
# 434               NaN
# 435    5/29/2019 0:00
# Name: Inactive Date, Length: 436, dtype: object

# %%
#Step 8, Calculate 1stDateofID, then calculate Returned to Active Date (Date of Idenfication on second record)
#{FIXED [ClientID],[Household Type]: MIN([Date of Identification]) }
#IF [NumRows_ClientID_HouseholdType]> 1 AND [1stDateofID] <> [Date of Identification] THEN [Date of Identification] ELSE NULL END
#If [Household Type Case Counter]>1 AND [1stDateofID] != [Date of Identification] THEN [Date of Identification] ELSE np.nan
df['1stDateofID'] = df['Client ID'].map(df.groupby('Client ID').agg({'Date of Identification':'min'})['Date of Identification']) #works
df['Return to Active Date'] = np.nan
df.loc[(df['Client ID Counter']>1) & (df['1stDateofID']!=df['Date of Identification'])
,"Return to Active Date"] = df['Date of Identification']
df['Return to Active Date'].value_counts()
# Out:
# 7/1/2019 0:00      9
# 7/1/2018 0:00      3
# 8/29/2018 0:00     2
# 8/9/2016 0:00      2
# 8/17/2016 0:00     2
# 1/8/2015 0:00      1
# 9/4/2021 0:00      1
# 5/25/2017 0:00     1
# 12/27/2020 0:00    1
# 5/17/2017 0:00     1
# 8/22/2017 0:00     1
# 2/8/2017 0:00      1
# 4/2/2020 0:00      1
# 7/10/2020 0:00     1
# 9/28/2020 0:00     1
# 9/19/2017 0:00     1
# 6/2/2015 0:00      1
# 7/6/2015 0:00      1
# 8/5/2021 0:00      1
# 8/7/2015 0:00      1
# 9/28/2016 0:00     1
# 4/11/2016 0:00     1
# 11/30/2016 0:00    1
# 8/27/2020 0:00     1
# 3/3/2018 0:00      1
# 8/29/2016 0:00     1
# 2/22/2018 0:00     1
# 9/26/2018 0:00     1
# Name: Return to Active Date, dtype: int64

# %%
# df.to_csv('PythonOutput.csv')
# df.groupby('Client ID').agg({'Household Type':'count','Client ID':'count'})
