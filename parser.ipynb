# %%
import pandas as pd
import numpy as np

# %%
#Step 1: Import document, Change Program Start Date to Date of Identification
df = pd.read_csv("BFZ_Aggregator_Report.csv")
df = df.rename(columns={"Program Start Date":"Date of Identification"})
df = df.drop(["Relationship","Family Name"],axis=1)
df
# Out:
#                     Name  Case Number  \
# 0          Abebe, Melaku        48450
# 1         Abreo, Richard         7649
# 2        Acosta, Michael         8039
# 3           Agboka, Alex        48894
# 4         Aguirre, Maria        52633
# ..                   ...          ...
# 442         Woods, Laura        43654
# 443    Woolfolk, William        50467
# 444  Worthington, Taylor        51829
# 445         Young, Linda        10194
# 446        Ytity, Ytiyti        48574
#
#                                 Program Name Veteran Status (HUD)  \
# 0    Arlington Zero: Chronic - Veterans Only                   No
# 1    Arlington Zero: Chronic - Veterans Only                   No
# 2    Arlington Zero: Chronic - Veterans Only                   No
# 3              Arlington Zero: Single Adults                   No
# 4                   Arlington Zero: Families                   No
# ..                                       ...                  ...
# 442  Arlington Zero: Chronic - Veterans Only                   No
# 443            Arlington Zero: Single Adults                   No
# 444  Arlington Zero: Chronic - Veterans Only                  Yes
# 445  Arlington Zero: Chronic - Veterans Only                   No
# 446  Arlington Zero: Chronic - Veterans Only                   No
#
#     Date of Identification Program End Date                Dismissal Reason
# 0           1/31/2019 0:00   6/19/2019 0:00       Exit to Permanent Housing
# 1           8/27/2015 0:00  10/30/2015 0:00       Exit to Permanent Housing
# 2           1/20/2015 0:00   1/22/2015 0:00  Service Completed Successfully
# 3            7/1/2019 0:00   7/24/2020 0:00       Exit to Permanent Housing
# 4           6/23/2021 0:00              NaN                             NaN
# ..                     ...              ...                             ...
# 442         3/28/2017 0:00   6/12/2017 0:00       Exit to Permanent Housing
# 443          7/1/2019 0:00   2/26/2020 0:00       Exit to Permanent Housing
# 444         3/17/2020 0:00  11/19/2020 0:00       Exit to Permanent Housing
# 445         11/2/2015 0:00    8/8/2016 0:00       Exit to Permanent Housing
# 446         9/20/2018 0:00   5/29/2019 0:00               Left Jurisdiction
#
# [447 rows x 7 columns]

# %%
#Step 2: Adding Case Number Counter
# case_counter = df.groupby('Case Number').count()['Name']
df['Case Number Counter'] = df['Case Number'].map(df.groupby('Case Number').count()['Name'])
df[df['Case Number Counter'] > 1]
# Out:
#                   Name  Case Number                             Program Name  \
# 36      Bhavsar, Meena        44078  Arlington Zero: Chronic - Veterans Only
# 37      Bhavsar, Meena        44078  Arlington Zero: Chronic - Veterans Only
# 49       Brown, Fatima        10489  Arlington Zero: Chronic - Veterans Only
# 50       Brown, Fatima        10489            Arlington Zero: Single Adults
# 51       Brown, Fatima        10489  Arlington Zero: Chronic - Veterans Only
# ..                 ...          ...                                      ...
# 433  Williams, Charlie         8563  Arlington Zero: Chronic - Veterans Only
# 434  Williams, Charlie         8563  Arlington Zero: Chronic - Veterans Only
# 435  Williams, Charlie         8563  Arlington Zero: Chronic - Veterans Only
# 439      Willis, Zayia        40681                 Arlington Zero: Families
# 440      Willis, Zayia        40681                      Arlington Zero: TAY
#
#     Veteran Status (HUD) Date of Identification Program End Date  \
# 36                    No         8/17/2016 0:00   8/17/2016 0:00
# 37                    No         3/22/2016 0:00   5/12/2017 0:00
# 49                    No         7/10/2020 0:00              NaN
# 50                    No          7/1/2019 0:00   6/22/2021 0:00
# 51                    No         7/10/2020 0:00              NaN
# ..                   ...                    ...              ...
# 433                   No        11/30/2016 0:00   2/27/2017 0:00
# 434                   No        10/15/2015 0:00   3/29/2016 0:00
# 435                   No         9/19/2017 0:00   6/30/2018 0:00
# 439   Data Not Collected          9/4/2021 0:00              NaN
# 440   Data Not Collected          5/7/2021 0:00              NaN
#
#                   Dismissal Reason  Case Number Counter
# 36               Removed from Pool                    2
# 37       Exit to Permanent Housing                    2
# 49                             NaN                    4
# 50               Removed from Pool                    4
# 51                             NaN                    4
# ..                             ...                  ...
# 433  Discharged for Non-Compliance                    3
# 434              Removed from Pool                    3
# 435                            NaN                    3
# 439                            NaN                    2
# 440                            NaN                    2
#
# [100 rows x 8 columns]

# %%
#Step 3: Adding Household Type Column
household_type = {"Arlington Zero: Chronic - Veterans Only":"Single Adults",
"Arlington Zero: Single Adults":"Single Adults",
"Arlington Zero: Families":"Families",
"Arlington Zero: TAY":"Youth"}
df['Household Type'] = df['Program Name'].map(household_type)
df
# Out:
#                     Name  Case Number  \
# 0          Abebe, Melaku        48450
# 1         Abreo, Richard         7649
# 2        Acosta, Michael         8039
# 3           Agboka, Alex        48894
# 4         Aguirre, Maria        52633
# ..                   ...          ...
# 442         Woods, Laura        43654
# 443    Woolfolk, William        50467
# 444  Worthington, Taylor        51829
# 445         Young, Linda        10194
# 446        Ytity, Ytiyti        48574
#
#                                 Program Name Veteran Status (HUD)  \
# 0    Arlington Zero: Chronic - Veterans Only                   No
# 1    Arlington Zero: Chronic - Veterans Only                   No
# 2    Arlington Zero: Chronic - Veterans Only                   No
# 3              Arlington Zero: Single Adults                   No
# 4                   Arlington Zero: Families                   No
# ..                                       ...                  ...
# 442  Arlington Zero: Chronic - Veterans Only                   No
# 443            Arlington Zero: Single Adults                   No
# 444  Arlington Zero: Chronic - Veterans Only                  Yes
# 445  Arlington Zero: Chronic - Veterans Only                   No
# 446  Arlington Zero: Chronic - Veterans Only                   No
#
#     Date of Identification Program End Date                Dismissal Reason  \
# 0           1/31/2019 0:00   6/19/2019 0:00       Exit to Permanent Housing
# 1           8/27/2015 0:00  10/30/2015 0:00       Exit to Permanent Housing
# 2           1/20/2015 0:00   1/22/2015 0:00  Service Completed Successfully
# 3            7/1/2019 0:00   7/24/2020 0:00       Exit to Permanent Housing
# 4           6/23/2021 0:00              NaN                             NaN
# ..                     ...              ...                             ...
# 442         3/28/2017 0:00   6/12/2017 0:00       Exit to Permanent Housing
# 443          7/1/2019 0:00   2/26/2020 0:00       Exit to Permanent Housing
# 444         3/17/2020 0:00  11/19/2020 0:00       Exit to Permanent Housing
# 445         11/2/2015 0:00    8/8/2016 0:00       Exit to Permanent Housing
# 446         9/20/2018 0:00   5/29/2019 0:00               Left Jurisdiction
#
#      Case Number Counter Household Type
# 0                      1  Single Adults
# 1                      1  Single Adults
# 2                      1  Single Adults
# 3                      1  Single Adults
# 4                      1       Families
# ..                   ...            ...
# 442                    1  Single Adults
# 443                    1  Single Adults
# 444                    1  Single Adults
# 445                    1  Single Adults
# 446                    1  Single Adults
#
# [447 rows x 9 columns]

# %%
#Step 4: Adding Chronic Column
#If client is in Chronic & Vet and 'No' to Veteran Status, then they are chronic
df['Chronic'] = np.nan
df.loc[(df['Program Name']=="Arlington Zero: Chronic - Veterans Only") & (df['Veteran Status (HUD)']=="No")
,"Chronic"] = "Yes"
df['Chronic'].value_counts()
# Out:
# Yes    233
# Name: Chronic, dtype: int64

# %%
#Step 5, remap all dismissal reasons
